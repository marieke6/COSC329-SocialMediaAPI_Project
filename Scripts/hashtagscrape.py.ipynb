# %%
import pandas as pd
import tweepy
import datetime

# %%
# display the data of tweets
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Retweet Count:{ith_tweet[5]}")
    print(f"Tweet Text:{ith_tweet[6]}")
    print(f"Hashtags Used:{ith_tweet[7]}")

# %%
# function in order to grab data
def data(words, date_since, numtweet):
      
    # Creating DataFrame using pandas
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following',
                               'followers', 'retweetcount', 'text', 'hashtags'])
      
    #Cursor() to search through twitter for the required tweets.
    tweets = tweepy.Cursor(api.search_tweets, q=words, lang="en",
                           since=date_since, tweet_mode='extended').items(numtweet)
    
    # get information about each tweet
    list_tweets = [tweet for tweet in tweets]
      
    i = 1  
     # information about each tweet
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
          
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
          
        #appending in DataFrame
        ith_tweet = [username, description, location, following,
                     followers, totaltweets, retweetcount, text, hashtext]
        db.loc[len(db)] = ith_tweet  # print tweet data on screen
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'data_tweets.csv'
      
    # save as a CSV file.
    db.to_csv(filename)
  
  
if __name__ == '__main__':
      
    # Enter your credentials
    # can be obtained on twitters developer page API v2.

    consumer_key = "ZY4YRvWXUFKngcrq1vV7xTEmZ"
    consumer_secret = "k2DbIF8l2LtTpnHr3i9EBj2IzOAxlNzbDgQH5s29O5gMr8Vdj1"
    access_key = "1408955612-dKpMXv4Oo0jIGSXVxH15ReLMxbaDIgGINmQ42Pf"
    access_secret = "EAaHvW7j8q9OtUOev30YFlhs9KfS3VGP0qIC6spsrJhr3"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
      
    
    print("Enter Twitter HashTag")
    words = input()
    print("Enter Date since in yyyy-mm--dd")
    date_since = input()
      
    #tweets you want to extract
    numtweet = 200  
    scrape(words, date_since, numtweet)
    print('completed!')
# Out:
# Enter Twitter HashTag
# covid
# Enter Date since in yyyy-mm--dd
# 2021-11-01
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Tweet 1:
# Username:backslashDMC
# Description:
# Location:
# Following Count:435
# Follower Count:109
# Total Tweets:22805
# Retweet Count:352
# Tweet Text:This past week I did a stretch in the ICU at my rural hospital - 100% of the ICU patients were unvaccinated and COVID+😢 https://t.co/QKf419BWOw
# Hashtags Used:[]
#
# Tweet 2:
# Username:JohnnyHoffs
# ...
